# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fb = pd.read_csv("../../fusiones_tiempo.csv")
print(fb)
# Out:
#      instancia     n     grafo  threads    tiempo
# 0            0   100     arbol        1  0.000000
# 1            1   100     arbol        2  0.400264
# 2            2   100     arbol        4  0.366809
# 3            3   100     arbol        8  0.428112
# 4            4   100     arbol       16  0.349530
# 5            5   100     arbol       32  0.271527
# 6            6   100     arbol        1  0.000000
# 7            7   100     arbol        2  0.415841
# 8            8   100     arbol        4  0.367285
# 9            9   100     arbol        8  0.419225
# 10          10   100     arbol       16  0.116527
# 11          11   100     arbol       32  0.222899
# 12          12   100     arbol        1  0.000000
# 13          13   100     arbol        2  0.235718
# 14          14   100     arbol        4  0.219691
# 15          15   100     arbol        8  0.333424
# 16          16   100     arbol       16  0.332976
# 17          17   100     arbol       32  0.191030
# 18          18   100     arbol        1  0.000000
# 19          19   100     arbol        2  0.177597
# 20          20   100     arbol        4  0.385661
# 21          21   100     arbol        8  0.409705
# 22          22   100     arbol       16  0.000000
# 23          23   100     arbol       32  0.211727
# 24          24   100     arbol        1  0.000000
# 25          25   100     arbol        2  0.178320
# 26          26   100     arbol        4  0.399854
# 27          27   100     arbol        8  0.256795
# 28          28   100     arbol       16  0.303951
# 29          29   100     arbol       32  0.310267
# ..         ...   ...       ...      ...       ...
# 870        870  1000  completo        1  0.000000
# 871        871  1000  completo        2  0.159329
# 872        872  1000  completo        4  0.285060
# 873        873  1000  completo        8  0.355925
# 874        874  1000  completo       16  0.383889
# 875        875  1000  completo       32  0.373186
# 876        876  1000  completo        1  0.000000
# 877        877  1000  completo        2  0.173965
# 878        878  1000  completo        4  0.297823
# 879        879  1000  completo        8  0.343576
# 880        880  1000  completo       16  0.355618
# 881        881  1000  completo       32  0.386523
# 882        882  1000  completo        1  0.000000
# 883        883  1000  completo        2  0.162495
# 884        884  1000  completo        4  0.289058
# 885        885  1000  completo        8  0.357980
# 886        886  1000  completo       16  0.381461
# 887        887  1000  completo       32  0.367991
# 888        888  1000  completo        1  0.000000
# 889        889  1000  completo        2  0.177222
# 890        890  1000  completo        4  0.283432
# 891        891  1000  completo        8  0.367090
# 892        892  1000  completo       16  0.374143
# 893        893  1000  completo       32  0.372842
# 894        894  1000  completo        1  0.000000
# 895        895  1000  completo        2  0.163553
# 896        896  1000  completo        4  0.286336
# 897        897  1000  completo        8  0.349070
# 898        898  1000  completo       16  0.370049
# 899        899  1000  completo       32  0.386515
#
# [900 rows x 5 columns]

# %%
d = {'n': [100], 'grafo': ["arbol"], 'threads': [1], 'tiempo': [1.0]}
data = pd.DataFrame(data=d)
data = data.drop([0])
for k in {1, 2, 4, 8, 16, 32, 64, 128}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'arbol']).loc[fb['threads'] == k]).loc[:, 'tiempo']
        data2 = {'n': [j], 'grafo': ["arbol"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))

        
for k in {1, 2, 4, 8, 16, 32, 64, 128}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'ralo']).loc[fb['threads'] == k]).loc[:, 'tiempo']
        data2 = {'n': [j], 'grafo': ["ralo"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))

for k in {1, 2, 4, 8, 16, 32, 64, 128}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'completo']).loc[fb['threads'] == k]).loc[:, 'tiempo']
        data2 = {'n': [j], 'grafo': ["completo"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))
print(data)
# Out:
#        n     grafo  threads    tiempo
# 0    100     arbol       32  0.241490
# 0    200     arbol       32  0.270462
# 0    300     arbol       32  0.127205
# 0    400     arbol       32  0.278542
# 0    500     arbol       32  0.194712
# 0    600     arbol       32  0.265959
# 0    700     arbol       32  0.312074
# 0    800     arbol       32  0.311972
# 0    900     arbol       32  0.296939
# 0   1000     arbol       32  0.332471
# 0    100     arbol        1  0.000000
# 0    200     arbol        1  0.000000
# 0    300     arbol        1  0.000000
# 0    400     arbol        1  0.000000
# 0    500     arbol        1  0.000000
# 0    600     arbol        1  0.000000
# 0    700     arbol        1  0.000000
# 0    800     arbol        1  0.000000
# 0    900     arbol        1  0.000000
# 0   1000     arbol        1  0.000000
# 0    100     arbol        2  0.281548
# 0    200     arbol        2  0.318578
# 0    300     arbol        2  0.394383
# 0    400     arbol        2  0.408097
# 0    500     arbol        2  0.446066
# 0    600     arbol        2  0.420308
# 0    700     arbol        2  0.444442
# 0    800     arbol        2  0.448498
# 0    900     arbol        2  0.450962
# 0   1000     arbol        2  0.437547
# ..   ...       ...      ...       ...
# 0    100  completo      128       NaN
# 0    200  completo      128       NaN
# 0    300  completo      128       NaN
# 0    400  completo      128       NaN
# 0    500  completo      128       NaN
# 0    600  completo      128       NaN
# 0    700  completo      128       NaN
# 0    800  completo      128       NaN
# 0    900  completo      128       NaN
# 0   1000  completo      128       NaN
# 0    100  completo        8  0.399674
# 0    200  completo        8  0.372445
# 0    300  completo        8  0.389254
# 0    400  completo        8  0.375106
# 0    500  completo        8  0.345791
# 0    600  completo        8  0.360911
# 0    700  completo        8  0.372972
# 0    800  completo        8  0.365051
# 0    900  completo        8  0.337445
# 0   1000  completo        8  0.354728
# 0    100  completo       16  0.351957
# 0    200  completo       16  0.340699
# 0    300  completo       16  0.370593
# 0    400  completo       16  0.369987
# 0    500  completo       16  0.367787
# 0    600  completo       16  0.378699
# 0    700  completo       16  0.390412
# 0    800  completo       16  0.379847
# 0    900  completo       16  0.372020
# 0   1000  completo       16  0.373032
#
# [240 rows x 4 columns]

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32"]);

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32"]);

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32"]);

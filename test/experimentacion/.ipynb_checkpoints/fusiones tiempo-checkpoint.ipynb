# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fb = pd.read_csv("../../fusiones_tiempo.csv")
print(fb)
# Out:
#       instancia     n     grafo  threads    tiempo
# 0             0   100     arbol        1  0.000000
# 1             1   100     arbol        2  0.430267
# 2             2   100     arbol        4  0.410837
# 3             3   100     arbol        8  0.311683
# 4             4   100     arbol       16  0.354674
# 5             5   100     arbol       32  0.273987
# 6             6   100     arbol       64  0.141856
# 7             7   100     arbol      128  0.060503
# 8             8   100     arbol        1  0.000000
# 9             9   100     arbol        2  0.430716
# 10           10   100     arbol        4  0.372524
# 11           11   100     arbol        8  0.266954
# 12           12   100     arbol       16  0.426312
# 13           13   100     arbol       32  0.065955
# 14           14   100     arbol       64  0.046545
# 15           15   100     arbol      128  0.058592
# 16           16   100     arbol        1  0.000000
# 17           17   100     arbol        2  0.399693
# 18           18   100     arbol        4  0.319254
# 19           19   100     arbol        8  0.301707
# 20           20   100     arbol       16  0.373915
# 21           21   100     arbol       32  0.262546
# 22           22   100     arbol       64  0.069435
# 23           23   100     arbol      128  0.046464
# 24           24   100     arbol        1  0.000000
# 25           25   100     arbol        2  0.430889
# 26           26   100     arbol        4  0.314780
# 27           27   100     arbol        8  0.328798
# 28           28   100     arbol       16  0.283554
# 29           29   100     arbol       32  0.247436
# ...         ...   ...       ...      ...       ...
# 2370       2370  1000  completo        4  0.252658
# 2371       2371  1000  completo        8  0.340824
# 2372       2372  1000  completo       16  0.363338
# 2373       2373  1000  completo       32  0.376949
# 2374       2374  1000  completo       64  0.373575
# 2375       2375  1000  completo      128  0.308232
# 2376       2376  1000  completo        1  0.000000
# 2377       2377  1000  completo        2  0.157940
# 2378       2378  1000  completo        4  0.266377
# 2379       2379  1000  completo        8  0.356014
# 2380       2380  1000  completo       16  0.367092
# 2381       2381  1000  completo       32  0.376831
# 2382       2382  1000  completo       64  0.368410
# 2383       2383  1000  completo      128  0.327763
# 2384       2384  1000  completo        1  0.000000
# 2385       2385  1000  completo        2  0.172796
# 2386       2386  1000  completo        4  0.280309
# 2387       2387  1000  completo        8  0.339606
# 2388       2388  1000  completo       16  0.367561
# 2389       2389  1000  completo       32  0.376775
# 2390       2390  1000  completo       64  0.372712
# 2391       2391  1000  completo      128  0.328390
# 2392       2392  1000  completo        1  0.000000
# 2393       2393  1000  completo        2  0.166470
# 2394       2394  1000  completo        4  0.267704
# 2395       2395  1000  completo        8  0.375411
# 2396       2396  1000  completo       16  0.353449
# 2397       2397  1000  completo       32  0.381216
# 2398       2398  1000  completo       64  0.370876
# 2399       2399  1000  completo      128  0.318932
#
# [2400 rows x 5 columns]

# %%
d = {'n': [100], 'grafo': ["arbol"], 'threads': [1], 'tiempo': [1.0]}
data = pd.DataFrame(data=d)
data = data.drop([0])
for k in {1, 2, 4, 8, 16, 32, 64, 128}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'arbol']).loc[fb['threads'] == k]).loc[:, 'tiempo']
        data2 = {'n': [j], 'grafo': ["arbol"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))

        
for k in {1, 2, 4, 8, 16, 32, 64, 128}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'ralo']).loc[fb['threads'] == k]).loc[:, 'tiempo']
        data2 = {'n': [j], 'grafo': ["ralo"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))

for k in {1, 2, 4, 8, 16, 32, 64, 128}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'completo']).loc[fb['threads'] == k]).loc[:, 'tiempo']
        data2 = {'n': [j], 'grafo': ["completo"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))
print(data)
# Out:
#        n     grafo  threads    tiempo
# 0    100     arbol       32  0.161026
# 0    200     arbol       32  0.106664
# 0    300     arbol       32  0.133454
# 0    400     arbol       32  0.169672
# 0    500     arbol       32  0.150265
# 0    600     arbol       32  0.092534
# 0    700     arbol       32  0.137498
# 0    800     arbol       32  0.174470
# 0    900     arbol       32  0.178491
# 0   1000     arbol       32  0.143356
# 0    100     arbol        1  0.000000
# 0    200     arbol        1  0.000000
# 0    300     arbol        1  0.000000
# 0    400     arbol        1  0.000000
# 0    500     arbol        1  0.000000
# 0    600     arbol        1  0.000000
# 0    700     arbol        1  0.000000
# 0    800     arbol        1  0.000000
# 0    900     arbol        1  0.000000
# 0   1000     arbol        1  0.000000
# 0    100     arbol        2  0.385099
# 0    200     arbol        2  0.372271
# 0    300     arbol        2  0.387838
# 0    400     arbol        2  0.435740
# 0    500     arbol        2  0.425416
# 0    600     arbol        2  0.429613
# 0    700     arbol        2  0.442707
# 0    800     arbol        2  0.436728
# 0    900     arbol        2  0.446485
# 0   1000     arbol        2  0.444679
# ..   ...       ...      ...       ...
# 0    100  completo      128  0.060476
# 0    200  completo      128  0.110714
# 0    300  completo      128  0.162042
# 0    400  completo      128  0.194908
# 0    500  completo      128  0.217290
# 0    600  completo      128  0.250413
# 0    700  completo      128  0.297671
# 0    800  completo      128  0.286015
# 0    900  completo      128  0.315053
# 0   1000  completo      128  0.317190
# 0    100  completo        8  0.347372
# 0    200  completo        8  0.398889
# 0    300  completo        8  0.379536
# 0    400  completo        8  0.387399
# 0    500  completo        8  0.377179
# 0    600  completo        8  0.368394
# 0    700  completo        8  0.372466
# 0    800  completo        8  0.360510
# 0    900  completo        8  0.358953
# 0   1000  completo        8  0.348586
# 0    100  completo       16  0.301592
# 0    200  completo       16  0.383327
# 0    300  completo       16  0.359598
# 0    400  completo       16  0.383030
# 0    500  completo       16  0.361073
# 0    600  completo       16  0.384240
# 0    700  completo       16  0.370306
# 0    800  completo       16  0.371940
# 0    900  completo       16  0.367162
# 0   1000  completo       16  0.368155
#
# [240 rows x 4 columns]

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 64]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 128]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32", "P64", "P128"]);

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 64]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 128]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32", "P64", "P128"]);

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 64]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 128]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32", "P64", "P128"]);

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fb = pd.read_csv("ComparacionThreads.csv")
print(fb)
# Out:
#       instancia     n     grafo  threads      tiempo
# 0             0   100     arbol        1    1.491570
# 1             1   100     arbol        2    1.600990
# 2             2   100     arbol        4    1.971380
# 3             3   100     arbol        8    2.566520
# 4             4   100     arbol       16    3.779760
# 5             5   100     arbol       32    4.017600
# 6             6   100     arbol        1    1.481610
# 7             7   100     arbol        2    1.582820
# 8             8   100     arbol        4    1.571170
# 9             9   100     arbol        8    6.594190
# 10           10   100     arbol       16   22.077300
# 11           11   100     arbol       32    0.937086
# 12           12   100     arbol        1    0.474244
# 13           13   100     arbol        2    0.485329
# 14           14   100     arbol        4    0.466511
# 15           15   100     arbol        8    0.672253
# 16           16   100     arbol       16    2.275300
# 17           17   100     arbol       32    1.708710
# 18           18   100     arbol        1    0.354131
# 19           19   100     arbol        2    0.342624
# 20           20   100     arbol        4    0.414964
# 21           21   100     arbol        8    0.603420
# 22           22   100     arbol       16    0.626908
# 23           23   100     arbol       32   13.289500
# 24           24   100     arbol        1    0.285180
# 25           25   100     arbol        2    0.276008
# 26           26   100     arbol        4    0.330641
# 27           27   100     arbol        8    0.408350
# 28           28   100     arbol       16    0.480347
# 29           29   100     arbol       32    0.614953
# ...         ...   ...       ...      ...         ...
# 1770       1770  1000  completo        1  257.906000
# 1771       1771  1000  completo        2  152.394000
# 1772       1772  1000  completo        4   86.095400
# 1773       1773  1000  completo        8   67.122400
# 1774       1774  1000  completo       16   72.118700
# 1775       1775  1000  completo       32  194.362000
# 1776       1776  1000  completo        1  253.350000
# 1777       1777  1000  completo        2  153.925000
# 1778       1778  1000  completo        4   89.136000
# 1779       1779  1000  completo        8   66.408400
# 1780       1780  1000  completo       16   71.931200
# 1781       1781  1000  completo       32   87.250700
# 1782       1782  1000  completo        1  253.691000
# 1783       1783  1000  completo        2  150.869000
# 1784       1784  1000  completo        4   85.267000
# 1785       1785  1000  completo        8   66.674600
# 1786       1786  1000  completo       16   64.575800
# 1787       1787  1000  completo       32   84.315000
# 1788       1788  1000  completo        1  258.513000
# 1789       1789  1000  completo        2  152.595000
# 1790       1790  1000  completo        4   89.505300
# 1791       1791  1000  completo        8   66.831200
# 1792       1792  1000  completo       16   65.249000
# 1793       1793  1000  completo       32  101.125000
# 1794       1794  1000  completo        1  264.466000
# 1795       1795  1000  completo        2  151.978000
# 1796       1796  1000  completo        4   86.252300
# 1797       1797  1000  completo        8   66.768800
# 1798       1798  1000  completo       16   69.498900
# 1799       1799  1000  completo       32  168.242000
#
# [1800 rows x 5 columns]

# %%
d = {'n': [100], 'grafo': ["arbol"], 'threads': [1], 'tiempo': [1.0]}
data = pd.DataFrame(data=d)
data = data.drop([0])
for k in {1, 2, 4, 8, 16, 32}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'arbol']).loc[fb['threads'] == k]).loc[:, ' tiempo']
        data2 = {'n': [j], 'grafo': ["arbol"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))

        
for k in {1, 2, 4, 8, 16, 32}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'ralo']).loc[fb['threads'] == k]).loc[:, ' tiempo']
        data2 = {'n': [j], 'grafo': ["ralo"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))

for k in {1, 2, 4, 8, 16, 32}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'completo']).loc[fb['threads'] == k]).loc[:, ' tiempo']
        data2 = {'n': [j], 'grafo': ["completo"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))
print(data)
# Out:
#        n     grafo  threads     tiempo
# 0    100     arbol       32   3.444154
# 0    200     arbol       32   4.905427
# 0    300     arbol       32   4.151027
# 0    400     arbol       32   5.336327
# 0    500     arbol       32   7.072095
# 0    600     arbol       32   8.536437
# 0    700     arbol       32  19.317136
# 0    800     arbol       32  15.349695
# 0    900     arbol       32  24.583990
# 0   1000     arbol       32  20.469205
# 0    100     arbol        1   0.549864
# 0    200     arbol        1   0.775631
# 0    300     arbol        1   1.524075
# 0    400     arbol        1   2.343549
# 0    500     arbol        1   3.492948
# 0    600     arbol        1   4.647275
# 0    700     arbol        1   6.231009
# 0    800     arbol        1   7.600156
# 0    900     arbol        1   9.449098
# 0   1000     arbol        1  11.617930
# 0    100     arbol        2   0.567818
# 0    200     arbol        2   0.588953
# 0    300     arbol        2   1.124384
# 0    400     arbol        2   1.724834
# 0    500     arbol        2   2.355537
# 0    600     arbol        2   3.304592
# 0    700     arbol        2   4.412365
# 0    800     arbol        2   5.236033
# 0    900     arbol        2   6.245409
# 0   1000     arbol        2   7.300088
# ..   ...       ...      ...        ...
# 0    100  completo        4   0.993647
# 0    200  completo        4   3.534927
# 0    300  completo        4   7.638868
# 0    400  completo        4  13.837500
# 0    500  completo        4  22.754340
# 0    600  completo        4  32.427550
# 0    700  completo        4  44.233700
# 0    800  completo        4  56.722880
# 0    900  completo        4  72.518640
# 0   1000  completo        4  87.199240
# 0    100  completo        8   0.808282
# 0    200  completo        8   2.915002
# 0    300  completo        8   6.136892
# 0    400  completo        8  10.900985
# 0    500  completo        8  17.831740
# 0    600  completo        8  25.221920
# 0    700  completo        8  33.065700
# 0    800  completo        8  42.865820
# 0    900  completo        8  53.704150
# 0   1000  completo        8  66.478420
# 0    100  completo       16   4.449764
# 0    200  completo       16   4.113800
# 0    300  completo       16   7.873922
# 0    400  completo       16  12.878567
# 0    500  completo       16  19.333610
# 0    600  completo       16  26.442620
# 0    700  completo       16  35.842650
# 0    800  completo       16  45.840300
# 0    900  completo       16  53.747860
# 0   1000  completo       16  67.149170
#
# [180 rows x 4 columns]

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32"]);

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32"]);

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32"]);

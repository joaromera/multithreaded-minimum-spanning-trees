# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fb = pd.read_csv("../../file.csv") # resultados nuestros en la macbook air
print(fb)
# Out:
#      instancia     n     grafo  threads        tiempo
# 0            0   100     arbol        1      0.154731
# 1            1   100     arbol        2      0.477016
# 2            2   100     arbol        4      0.513301
# 3            3   100     arbol        8     95.336000
# 4            4   100     arbol       16      0.575419
# 5            5   100     arbol       32    717.548000
# 6            6   100     arbol        1      1.048160
# 7            7   100     arbol        2      2.085070
# 8            8   100     arbol        4      0.752366
# 9            9   100     arbol        8      0.892179
# 10          10   100     arbol       16     21.229300
# 11          11   100     arbol       32      6.282090
# 12          12   100     arbol        1      1.072970
# 13          13   100     arbol        2      1.081800
# 14          14   100     arbol        4      2.610620
# 15          15   100     arbol        8     27.818200
# ...

# %%
d = {'n': [100], 'grafo': ["arbol"], 'threads': [1], 'tiempo': [1.0]}
data = pd.DataFrame(data=d)
data = data.drop([0])
for k in {1, 2, 4, 8, 16, 32}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'arbol']).loc[fb['threads'] == k]).loc[:, 'tiempo']
        data2 = {'n': [j], 'grafo': ["arbol"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))

        
for k in {1, 2, 4, 8, 16, 32}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'ralo']).loc[fb['threads'] == k]).loc[:, 'tiempo']
        data2 = {'n': [j], 'grafo': ["ralo"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))

for k in {1, 2, 4, 8, 16, 32}:
    for j in range(100,1001,100):
        data1 = (((fb.loc[fb['n'] == j]).loc[fb['grafo'] == 'completo']).loc[fb['threads'] == k]).loc[:, 'tiempo']
        data2 = {'n': [j], 'grafo': ["completo"], 'threads': [k], 'tiempo': [data1.mean()]}
        data = data.append(pd.DataFrame(data=data2))
print(data)
# Out:
#        n     grafo  threads       tiempo
# 0    100     arbol       32   388.394552
# 0    200     arbol       32   632.850140
# 0    300     arbol       32    27.755680
# 0    400     arbol       32   660.936200
# 0    500     arbol       32   140.273440
# 0    600     arbol       32   391.917580
# 0    700     arbol       32   650.322800
# 0    800     arbol       32   617.854200
# 0    900     arbol       32   422.580800
# 0   1000     arbol       32   587.634400
# 0    100     arbol        1     0.708917
# 0    200     arbol        1     0.703463
# 0    300     arbol        1     0.595016
# 0    400     arbol        1     0.604143
# 0    500     arbol        1     0.476588
# 0    600     arbol        1     0.399954
# 0    700     arbol        1     0.446189
# 0    800     arbol        1     0.503888
# 0    900     arbol        1     0.584610
# 0   1000     arbol        1     0.677918
# 0    100     arbol        2     1.148095
# 0    200     arbol        2     1.578201
# ...

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'arbol']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32"]);

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'ralo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32"]);

# %%
#Grafico para comparacion con arboles

data2 = data.loc[data['threads'] == 1]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 2]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 4]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 8]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 16]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

data2 = data.loc[data['threads'] == 32]
data3 = data2.loc[data2['grafo'] == 'completo']
ax1 = sns.lineplot(x="n", y="tiempo", data=data3);

plt.ylabel("tiempo(ms)");
plt.xlabel("n");
ax1.legend(["S1", "P2", "P4", "P8", "P16", "P32"]);
